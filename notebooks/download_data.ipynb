# %%
import gdown

# %%
FOLDER_URL = "https://drive.google.com/drive/folders/1i6mAZvKNhrwkA6QRkaZcScXeyADqqmnZ"

# %%
filenames = gdown.download_folder(FOLDER_URL, output="../data") # 下載檔案
# Out:
# Retrieving folder contents
# Processing file 1EnN3fP3oP5WlwBYSgzti0bL-8ClEq7we CityA Ground Truth Data.csv (1).gz
# Processing file 1yhoOjsSEr3lGAVy9F6C75ddqb97ONdVS CityB Challenge Data.csv.gz
# Processing file 1kOy1GyjtCDWRg0skF-i5H2ywSFi_qddm CityC Challenge Data.csv.gz
# Processing file 1y-Q_rltXRgA5YcH8s8edhbKEyJk82J8U CityD Challenge Data (1).csv.gz
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1EnN3fP3oP5WlwBYSgzti0bL-8ClEq7we
# From (redirected): https://drive.google.com/uc?id=1EnN3fP3oP5WlwBYSgzti0bL-8ClEq7we&confirm=t&uuid=ab6019e4-4975-4b28-a23a-f2e7f6023f3e
# To: d:\Repos\AI_term_project\data\CityA Ground Truth Data.csv (1).gz
# 100%|██████████| 419M/419M [00:12<00:00, 32.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1yhoOjsSEr3lGAVy9F6C75ddqb97ONdVS
# ...

# %%
print("orz pytree")
